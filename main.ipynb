# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from six.moves import urllib
import warnings
warnings.filterwarnings("ignore")

# %%
data_dir= "./data/"
os.makedirs(data_dir, exist_ok=True)

data_url = "https://raw.githubusercontent.com/mohitmahiyt/cardataset/refs/heads/main/cars_dataset.csv"

filename = os.path.basename(data_url)
print(f"Downloading:{filename}")

filepath = os.path.join(data_dir, filename)
print(f"downloading at: {filepath}")

urllib.request.urlretrieve(data_url, filepath)
print(f"downloading completed...")
# Out:
# Downloading:cars_dataset.csv
# downloading at: ./data/cars_dataset.csv
# downloading completed...

# %%
df = pd.read_csv("./data/cars_dataset.csv")
df
# Out:
#        car data set                  NaN        NaN.1        NaN.2 NaN.3  \
# 0               NaN                  NaN          NaN          NaN   NaN
# 1               NaN                  NaN          NaN          NaN   NaN
# 2               NaN                  NaN          NaN          NaN   NaN
# 3               NaN                  NaN          NaN          NaN   NaN
# 4               NaN                  NaN          NaN          NaN   NaN
# ...             ...                  ...          ...          ...   ...
# 15807       30016.0  Bentley Continental      Bentley  Continental    10
# 15808       30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost     4
# 15809       30018.0  Bentley Continental      Bentley  Continental     9
# 15810       30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso     2
# 15811       30020.0  Bentley Continental      Bentley  Continental     9
#
#        NaN.4       NaN.5   NaN.6      NaN.7 NaN.8 NaN.9 NaN.10 NaN.11  \
# ...

# %%
df.head(20)
# Out:
#     car data set          NaN   NaN.1  NaN.2        NaN.3      NaN.4  \
# 0            NaN          NaN     NaN    NaN          NaN        NaN
# 1            NaN          NaN     NaN    NaN          NaN        NaN
# 2            NaN          NaN     NaN    NaN          NaN        NaN
# 3            NaN          NaN     NaN    NaN          NaN        NaN
# 4            NaN          NaN     NaN    NaN          NaN        NaN
# 5            NaN          NaN     NaN    NaN          NaN        NaN
# 6            NaN          NaN     NaN    NaN          NaN        NaN
# 7            NaN          NaN     NaN    NaN          NaN        NaN
# 8            NaN          NaN     NaN    NaN          NaN        NaN
# 9            NaN          NaN     NaN    NaN          NaN        NaN
# 10           NaN     car_name   brand  model  vehicle_age  km_driven
# 11           1.0  Maruti Alto  Maruti   Alto            9      53800
# 12           2.0  Maruti Alto  Maruti   Alto           11      11000
# ...

# %%
df = pd.read_csv("./data/cars_dataset.csv", header=11)
df
# Out:
#            NaN             car_name        brand        model  vehicle_age  \
# 0          1.0          Maruti Alto       Maruti         Alto          9.0
# 1          2.0          Maruti Alto       Maruti         Alto         11.0
# 2          3.0          Maruti Alto       Maruti         Alto         11.0
# 3          NaN                  NaN          NaN          NaN          NaN
# 4          NaN                  NaN          NaN          NaN          NaN
# ...        ...                  ...          ...          ...          ...
# 15796  30016.0  Bentley Continental      Bentley  Continental         10.0
# 15797  30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0
# 15798  30018.0  Bentley Continental      Bentley  Continental          9.0
# 15799  30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0
# 15800  30020.0  Bentley Continental      Bentley  Continental          9.0
#
# ...

# %%
df.isnull().sum()
# Out:
# NaN                    390
# car_name               390
# brand                  390
# model                  390
# vehicle_age            390
# km_driven              390
# seller_type            390
# fuel_type              390
# transmission_type      390
# mileage                390
# engine                 390
# max_power              390
# seats                  390
# selling_price          390
#  my_car              15801
# dtype: int64

# %%
df.drop(' my_car', axis=1, inplace=True)

# %%
df
# Out:
#            NaN             car_name        brand        model  vehicle_age  \
# 0          1.0          Maruti Alto       Maruti         Alto          9.0
# 1          2.0          Maruti Alto       Maruti         Alto         11.0
# 2          3.0          Maruti Alto       Maruti         Alto         11.0
# 3          NaN                  NaN          NaN          NaN          NaN
# 4          NaN                  NaN          NaN          NaN          NaN
# ...        ...                  ...          ...          ...          ...
# 15796  30016.0  Bentley Continental      Bentley  Continental         10.0
# 15797  30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0
# 15798  30018.0  Bentley Continental      Bentley  Continental          9.0
# 15799  30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0
# 15800  30020.0  Bentley Continental      Bentley  Continental          9.0
#
# ...

# %%
df.isnull().sum()
# Out:
# NaN                  390
# car_name             390
# brand                390
# model                390
# vehicle_age          390
# km_driven            390
# seller_type          390
# fuel_type            390
# transmission_type    390
# mileage              390
# engine               390
# max_power            390
# seats                390
# selling_price        390
# dtype: int64

# %%
df[df.isna().all(axis=1)]
# Out:
#       NaN car_name brand model  vehicle_age  km_driven seller_type fuel_type  \
# 3     NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# 4     NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# 5     NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# 6     NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# 9     NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# ...   ...      ...   ...   ...          ...        ...         ...       ...
# 1046  NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# 1047  NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# 1075  NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# 1113  NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
# 1144  NaN      NaN   NaN   NaN          NaN        NaN         NaN       NaN
#
# ...

# %%
df.dropna(how='all', inplace=True)

# %%
df
# Out:
#            NaN             car_name        brand        model  vehicle_age  \
# 0          1.0          Maruti Alto       Maruti         Alto          9.0
# 1          2.0          Maruti Alto       Maruti         Alto         11.0
# 2          3.0          Maruti Alto       Maruti         Alto         11.0
# 7          4.0          Maruti Alto       Maruti         Alto         10.0
# 8          5.0          Maruti Alto       Maruti         Alto         11.0
# ...        ...                  ...          ...          ...          ...
# 15796  30016.0  Bentley Continental      Bentley  Continental         10.0
# 15797  30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0
# 15798  30018.0  Bentley Continental      Bentley  Continental          9.0
# 15799  30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0
# 15800  30020.0  Bentley Continental      Bentley  Continental          9.0
#
# ...

# %%
df.isnull().sum()
# Out:
# NaN                  0
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df
# Out:
#            NaN             car_name        brand        model  vehicle_age  \
# 0          1.0          Maruti Alto       Maruti         Alto          9.0
# 1          2.0          Maruti Alto       Maruti         Alto         11.0
# 2          3.0          Maruti Alto       Maruti         Alto         11.0
# 7          4.0          Maruti Alto       Maruti         Alto         10.0
# 8          5.0          Maruti Alto       Maruti         Alto         11.0
# ...        ...                  ...          ...          ...          ...
# 15796  30016.0  Bentley Continental      Bentley  Continental         10.0
# 15797  30017.0    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0
# 15798  30018.0  Bentley Continental      Bentley  Continental          9.0
# 15799  30019.0    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0
# 15800  30020.0  Bentley Continental      Bentley  Continental          9.0
#
# ...

# %%
df.drop('NaN', axis=1, inplace=True)

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto          9.0    53800.0
# 1              Maruti Alto       Maruti         Alto         11.0    11000.0
# 2              Maruti Alto       Maruti         Alto         11.0    80000.0
# 7              Maruti Alto       Maruti         Alto         10.0    57000.0
# 8              Maruti Alto       Maruti         Alto         11.0    72000.0
# ...                    ...          ...          ...          ...        ...
# 15796  Bentley Continental      Bentley  Continental         10.0    30000.0
# 15797    Rolls-Royce Ghost  Rolls-Royce        Ghost          4.0     5000.0
# 15798  Bentley Continental      Bentley  Continental          9.0    37500.0
# 15799    Ferrari GTC4Lusso      Ferrari    GTC4Lusso          2.0     3800.0
# 15800  Bentley Continental      Bentley  Continental          9.0     9000.0
#
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
# ...

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df[['vehicle_age', 'km_driven', 'engine', 'seats']] = df[['vehicle_age', 'km_driven', 'engine', 'seats']].astype(int)

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
# ...

# %%
df.to_csv("./data/cleaned_cars_dataset.csv", index=False)

# %%
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost:3306/{db}".format(user="root", pw="root", db="car_price_db_re11am"))

# %%
df.to_sql(con=engine, name="cleaned_cars_dataset", index=False, if_exists="replace")
# Out:
# 15411

# %%
df = pd.read_sql(con=engine, sql="select * from cleaned_cars_dataset;")
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
# ...

# %% [markdown]
# # EDA

# %%
df = pd.read_sql(con=engine, sql="select * from cleaned_cars_dataset;")
df
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
# ...

# %%
# splitting numerical and categorical columns

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# car_name              object
# brand                 object
# model                 object
# vehicle_age            int64
# km_driven              int64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine                 int64
# max_power            float64
# seats                  int64
# selling_price        float64
# dtype: object

# %%
df['car_name'].dtype == 'O'
# Out:
# True

# %%
df['max_power'].dtype != 'O'
# Out:
# True

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype !='O']
print(f"There are {len(numerical_features)} numerical_features named:{numerical_features}")

categorical_features = [feature for feature in df.columns if df[feature].dtype =='O']
print(f"There are {len(categorical_features)} categorical_features named:{categorical_features}")
# Out:
# There are 7 numerical_features named:['vehicle_age', 'km_driven', 'mileage', 'engine', 'max_power', 'seats', 'selling_price']
# There are 6 categorical_features named:['car_name', 'brand', 'model', 'seller_type', 'fuel_type', 'transmission_type']

# %%
# univaiant analysis

plt.figure(figsize=(15,10))
plt.suptitle("Univariant Analysis on Numerical Features")

for i in  range(len(numerical_features)):
    plt.subplot(3,3,i+1)
    sns.kdeplot(x = df[numerical_features[i]], color='r', shade=True)
    plt.tight_layout()

# %%
# detecting outliers

plt.figure(figsize=(15,10))
plt.suptitle("Outliers in Numerical Features")

for i in  range(len(numerical_features)):
    plt.subplot(3,3,i+1)
    sns.boxplot(x = df[numerical_features[i]], color='r')
    plt.tight_layout()

# %%
# univariant analysis on categorical features

plt.figure(figsize=(15,30))
plt.suptitle("Univariant Analysis on Categorical Features")

for i in  range(len(categorical_features)):
    plt.subplot(6,1,i+1)
    sns.countplot(x = df[categorical_features[i]], order=df[categorical_features[i]].value_counts().index, palette="Set1", ec="black", linewidth=2.5)
    plt.tight_layout()
    plt.xticks(rotation=90)

# %% [markdown]
# # Bivariant Analysis

# %%
plt.figure(figsize=(15,15))
plt.suptitle("Bivariant Analysis on Numerical Features")

for i in  range(len(numerical_features)):
    plt.subplot(4,2,i+1)
    sns.scatterplot(x=df[numerical_features[i]], y=df['selling_price'])
    #sns.lineplot(x=df[numerical_features[i]], y=df['selling_price'])

    plt.tight_layout()

# %%
# MULTIVARIANT ANALYSIS



plt.figure(figsize=(15,10))
plt.suptitle("Multivariant Analysis on Numerical Features")
sns.heatmap(df[numerical_features].corr(), annot=True, vmin=-1, vmax=+1, cmap="plasma")
# Out:
# <Axes: >

# %% [markdown]
# # Visualisation

# %%
# target column


plt.figure(figsize=(15,5))
plt.suptitle("Selling Price distribution")

sns.histplot(x=df['selling_price'], bins=200, color = "green", kde=True)
plt.xlim(0,10000000)
# Out:
# (0.0, 10000000.0)

# %% [markdown]
# # Top 10 most selling cars in dataset

# %%
top_10_most_sold_cars=df['car_name'].value_counts().head(10)

plt.figure(figsize=(15,5))
plt.suptitle("Top 10 Most Sold Cars in dataset", fontsize=30, fontstyle='italic')
ax=sns.barplot(x=top_10_most_sold_cars.index, y=top_10_most_sold_cars.values, palette="Set1", ec='black', linewidth=2.5)

for i in range(len(top_10_most_sold_cars.values)):
    plt.bar_label(ax.containers[i], label_type='edge')

# %% [markdown]
# # Top 10 most selling car brand in dataset

# %%
# Find top 10 most sold car brands
top_10_most_sold_brands = df['brand'].value_counts().head(10)

# Plot
plt.figure(figsize=(15,5))
plt.suptitle("Top 10 Most Sold Car Brands in dataset", fontsize=30, fontstyle='italic')
ax=sns.barplot(x=top_10_most_sold_brands.index, 
            y=top_10_most_sold_brands.values, 
            palette="Set2", ec='black', linewidth=2.5)

for i in range(len(top_10_most_sold_brands.values)):
    plt.bar_label(ax.containers[i], label_type='edge')


plt.show()

# %% [markdown]
# # Top 10 most selling car model in dataset

# %%
# Find top 10 most sold car brands
top_10_most_sold_model = df['model'].value_counts().head(10)

# Plot
plt.figure(figsize=(15,5))
plt.suptitle("Top 10 Most Sold Car model in dataset", fontsize=30, fontstyle='italic')
ax=sns.barplot(x=top_10_most_sold_model.index, 
            y=top_10_most_sold_model.values, 
            palette="Set3", ec='black', linewidth=2.5)

for i in range(len(top_10_most_sold_model.values)):
    plt.bar_label(ax.containers[i], label_type='edge')


plt.show()

# %% [markdown]
# # Top 10 most costlier cars in dataset

# %%
def format_values(value):
    if value>=10000000:
        return f"{value/10000000:.2f} Crores"
    elif value>=100000:
        return f"{value/100000:.2f} Lakhs"
    elif value>=1000:
        return f"{value/1000:.2f} K"
    else:
        return str(int(value))

# %%
top_10_most_costlier_cars =df.groupby('car_name')['selling_price'].max().sort_values(ascending=False).head(10)
print(top_10_most_costlier_cars)
# Plot
plt.figure(figsize=(15,5))
plt.suptitle("Top 10 Most Costlier Cars in dataset", fontsize=30, fontstyle='italic')
ax=sns.barplot(x=top_10_most_costlier_cars.index, 
            y=top_10_most_costlier_cars.values, 
            palette="Set3", ec='black', linewidth=2.5)

formatted_labels = [format_values(i) for i in top_10_most_costlier_cars.values]

for bar, label in zip(ax.containers, formatted_labels):
    plt.bar_label(container=bar, labels=[label], label_type='edge')

plt.xticks(rotation=45)
plt.show()
# Out:
# car_name
# Ferrari GTC4Lusso        39500000.0
# Rolls-Royce Ghost        24200000.0
# Bentley Continental      14500000.0
# Mercedes-Benz S-Class    13000000.0
# Porsche Cayenne          11100000.0
# Land Rover Rover          9200000.0
# BMW 7                     8500000.0
# BMW Z4                    8250000.0
# Volvo XC                  8195000.0
# BMW X5                    8100000.0
# Name: selling_price, dtype: float64

# %% [markdown]
# # Impact of fuel on selling price

# %%
fuel_type_price=df.groupby('fuel_type')['selling_price'].median().sort_values(ascending=False)
print(fuel_type_price)
# Plot
plt.figure(figsize=(15,5))
plt.suptitle("Impact of fuel on selling price", fontsize=30, fontstyle='italic')
ax=sns.barplot(x=fuel_type_price.index, 
            y=fuel_type_price.values, 
            palette="Set3", ec='black', linewidth=2.5)

formatted_labels = [format_values(i) for i in fuel_type_price.values]

for bar, label in zip(ax.containers, formatted_labels):
    plt.bar_label(container=bar, labels=[label], label_type='edge')

plt.xticks(rotation=45)
plt.show()
# Out:
# fuel_type
# Electric    1857500.0
# Diesel       700000.0
# Petrol       460000.0
# CNG          370000.0
# LPG          182500.0
# Name: selling_price, dtype: float64

# %% [markdown]
# # Most sold fuel type cars

# %%
plt.figure(figsize=(15,5))
plt.suptitle("Most sold fuel type cars", fontsize=30, fontstyle='italic')
ax=sns.countplot(x=df['fuel_type'],palette="Set3", ec='black', linewidth=2.5, order=df['fuel_type'].value_counts().index)

formatted_labels = [format_values(i) for i in df['fuel_type'].value_counts().values]

for bar, label in zip(ax.containers, formatted_labels):
    plt.bar_label(container=bar, labels=[label], label_type='edge')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Impact of vehicle age on selling price

# %%
plt.figure(figsize=(15,5))
plt.suptitle("Impact of vehicle age on selling price ", fontsize=30, fontstyle='italic')
sns.lineplot(x=df['vehicle_age'],y=df['selling_price'], color='r')


plt.show()

# %%
# impact of transmission type on selling price

transmission_type_price=df.groupby('transmission_type')['selling_price'].median().sort_values(ascending=False)
print(transmission_type_price)
# Plot
plt.figure(figsize=(15,5))
plt.suptitle("Impact of transmission type on selling price", fontsize=30, fontstyle='italic')
ax=sns.barplot(x=transmission_type_price.index, 
            y=transmission_type_price.values, 
            palette="Set1", ec='black', linewidth=2.5)

formatted_labels = [format_values(i) for i in transmission_type_price.values]

for bar, label in zip(ax.containers, formatted_labels):
    plt.bar_label(container=bar, labels=[label], label_type='edge')

plt.xticks(rotation=45)
plt.show()
# Out:
# transmission_type
# Automatic    1057000.0
# Manual        500000.0
# Name: selling_price, dtype: float64

# %%
# Most sold transmission type cars

plt.figure(figsize=(15,5))
plt.suptitle("Most sold transmisson type cars", fontsize=30, fontstyle='italic')
ax=sns.countplot(x=df['transmission_type'],palette="Set2", ec='black', linewidth=2.5, order=df['transmission_type'].value_counts().index)

formatted_labels = [format_values(i) for i in df['transmission_type'].value_counts().values]

for bar, label in zip(ax.containers, formatted_labels):
    plt.bar_label(container=bar, labels=[label], label_type='edge')

plt.xticks(rotation=45)
plt.show()

# %%
# impact of seller type on selling price
# Most preferred seller in market

# %% [markdown]
# # Final Report
# - Manual cars are more preffered than automatic
# - Automatic cars are much costlier than manual cars

# %% [markdown]
# # FEATURE ENGINEERING

# %%
df_model = pd.read_csv("./data/cleaned_cars_dataset.csv")
df_model
# Out:
#                   car_name        brand        model  vehicle_age  km_driven  \
# 0              Maruti Alto       Maruti         Alto            9      53800
# 1              Maruti Alto       Maruti         Alto           11      11000
# 2              Maruti Alto       Maruti         Alto           11      80000
# 3              Maruti Alto       Maruti         Alto           10      57000
# 4              Maruti Alto       Maruti         Alto           11      72000
# ...                    ...          ...          ...          ...        ...
# 15406  Bentley Continental      Bentley  Continental           10      30000
# 15407    Rolls-Royce Ghost  Rolls-Royce        Ghost            4       5000
# 15408  Bentley Continental      Bentley  Continental            9      37500
# 15409    Ferrari GTC4Lusso      Ferrari    GTC4Lusso            2       3800
# 15410  Bentley Continental      Bentley  Continental            9       9000
#
# ...

# %%
pd.Categorical(df_model['model'])
# Out:
# ['Alto', 'Alto', 'Alto', 'Alto', 'Alto', ..., 'Continental', 'Ghost', 'Continental', 'GTC4Lusso', 'Continental']
# Length: 15411
# Categories (120, object): ['3', '5', '6', '7', ..., 'Z4', 'i10', 'i20', 'redi-GO']

# %%
df_model.drop(['car_name', 'brand', 'model'], axis=1, inplace=True)

# %%
df_model=pd.get_dummies(df_model, dtype=int)
df_model
# Out:
#        vehicle_age  km_driven  mileage  engine  max_power  seats  \
# 0                9      53800    26.83     796       38.4      5
# 1               11      11000    26.83     796       38.4      5
# 2               11      80000    26.83     796       38.4      5
# 3               10      57000    26.83     796       38.4      5
# 4               11      72000    26.83     796       38.4      5
# ...            ...        ...      ...     ...        ...    ...
# 15406           10      30000     8.60    5998      552.0      4
# 15407            4       5000    10.20    6592      563.0      4
# 15408            9      37500     6.00    5998      600.0      5
# 15409            2       3800     4.00    3855      601.0      4
# 15410            9       9000     9.50    5998      626.0      4
#
#        selling_price  seller_type_Dealer  seller_type_Individual  \
# 0           235000.0                   1                       0
# ...

# %% [markdown]
# # Feature Matrix => separating independent and dependent variables

# %%
X = df_model.drop('selling_price',axis=1)
X
# Out:
#        vehicle_age  km_driven  mileage  engine  max_power  seats  \
# 0                9      53800    26.83     796       38.4      5
# 1               11      11000    26.83     796       38.4      5
# 2               11      80000    26.83     796       38.4      5
# 3               10      57000    26.83     796       38.4      5
# 4               11      72000    26.83     796       38.4      5
# ...            ...        ...      ...     ...        ...    ...
# 15406           10      30000     8.60    5998      552.0      4
# 15407            4       5000    10.20    6592      563.0      4
# 15408            9      37500     6.00    5998      600.0      5
# 15409            2       3800     4.00    3855      601.0      4
# 15410            9       9000     9.50    5998      626.0      4
#
#        seller_type_Dealer  seller_type_Individual  \
# 0                       1                       0
# 1                       1                       0
# ...

# %%
y = df_model['selling_price']
y
# Out:
# 0          235000.0
# 1          185000.0
# 2          150000.0
# 3          172000.0
# 4          125000.0
#             ...
# 15406     8100000.0
# 15407    24200000.0
# 15408     5200000.0
# 15409    39500000.0
# 15410    14500000.0
# Name: selling_price, Length: 15411, dtype: float64

# %%
# train test split

from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=0)

# %%
X_train
# Out:
#        vehicle_age  km_driven  mileage  engine  max_power  seats  \
# 14557            5      43000    19.59    1995     184.00      5
# 9069             7      48000    20.73    1373      91.10      5
# 4546             2       5000    25.32    1198      77.00      6
# 14105            7      60004    19.27    2143     170.00      5
# 14675           10      22800    11.74    1796     186.00      5
# ...            ...        ...      ...     ...        ...    ...
# 13123           11      60000    16.55    1968     140.00      5
# 3264             9      35000    22.07    1199      73.90      5
# 9845             5      72000    21.70    1498      98.96      5
# 10799           11      41000    20.54    1598     103.60      5
# 2732             9      75000    19.81    1086      68.05      5
#
#        seller_type_Dealer  seller_type_Individual  \
# 14557                   1                       0
# 9069                    1                       0
# ...

# %%
X_test
# Out:
#        vehicle_age  km_driven  mileage  engine  max_power  seats  \
# 5122             4      30000    20.89    1197      81.80      5
# 9792             4      39884    23.00    1498      98.96      5
# 8379             5      65000    22.54    1396      88.73      5
# 10718            8      44900    17.20    1197     103.60      5
# 641              3      12000    25.17     799      53.30      5
# ...            ...        ...      ...     ...        ...    ...
# 4703            12      97341    20.36    1197      78.90      5
# 15380            4      11500    11.50    2996     362.00      5
# 2483            11     150821    18.90     998      67.10      5
# 13028            2      12750    17.00    1956     138.10      5
# 8522             4      30000    22.54    1396      88.73      5
#
#        seller_type_Dealer  seller_type_Individual  \
# 5122                    1                       0
# 9792                    1                       0
# ...

# %%
y_train
# Out:
# 14557    2250000.0
# 9069      545000.0
# 4546      700000.0
# 14105    1349000.0
# 14675    1350000.0
#            ...
# 13123    1250000.0
# 3264      290000.0
# 9845      675000.0
# 10799     285000.0
# 2732      235000.0
# Name: selling_price, Length: 12328, dtype: float64

# %%
y_test
# Out:
# 5122      465000.0
# 9792      880000.0
# 8379      675000.0
# 10718     495000.0
# 641       330000.0
#            ...
# 4703      165000.0
# 15380    7595000.0
# 2483      160000.0
# 13028    1750000.0
# 8522      760000.0
# Name: selling_price, Length: 3083, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.34340311, -0.2368301 , -0.03032915, ..., -0.98999168,
#          1.96890383, -1.96890383],
#        [ 0.31843907, -0.14368077,  0.24281279, ...,  1.0101095 ,
#         -0.50789682,  0.50789682],
#        [-1.33616638, -0.94476498,  1.34256853, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        ...,
#        [-0.34340311,  0.303436  ,  0.47522305, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        [ 1.64212343, -0.27408983,  0.19728914, ..., -0.98999168,
#         -0.50789682,  0.50789682],
#        [ 0.98028125,  0.35932559,  0.02238245, ...,  1.0101095 ,
#         -0.50789682,  0.50789682]], shape=(12328, 16))

# %%
pd.DataFrame(X_test_scaled, columns= X.columns)
# Out:
#       vehicle_age  km_driven   mileage    engine  max_power     seats  \
# 0       -0.674324  -0.479018  0.281149 -0.552167  -0.433991 -0.404477
# 1       -0.674324  -0.294881  0.786701  0.028073  -0.033277 -0.404477
# 2       -0.343403   0.173027  0.676486 -0.168554  -0.272164 -0.404477
# 3        0.649360  -0.201433 -0.602969 -0.552167   0.075074 -0.404477
# 4       -1.005245  -0.814356  1.306629 -1.319395  -1.099512 -0.404477
# ...           ...        ...       ...       ...        ...       ...
# 3078     1.973045   0.775535  0.154161 -0.552167  -0.501710 -0.404477
# 3079    -0.674324  -0.823671 -1.968679  2.915778   6.109131 -0.404477
# 3080     1.642123   1.771861 -0.195652 -0.935781  -0.777259 -0.404477
# 3081    -1.336166  -0.800384 -0.650888  0.910963   0.880705 -0.404477
# 3082    -0.674324  -0.479018  0.676486 -0.168554  -0.272164 -0.404477
#
#       seller_type_Dealer  seller_type_Individual  \
# 0               0.785088               -0.766975
# ...

# %%
# checking imp features
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X_train_scaled, y_train)
# Out:
# ExtraTreesRegressor()

# %%
imp_features = pd.Series(model.feature_importances_,index= X_train.columns)
imp_features.nlargest(15).plot(kind="barh", color="g")
# Out:
# <Axes: >

# %% [markdown]
# # Model Building and Evaluation

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score, r2_score

# %%
models = [LinearRegression, Ridge, Lasso, SVR, DecisionTreeRegressor, RandomForestRegressor]

mae = []
mse = []
rmse=[]
evs = []
r_squared_score = []

for model in models:
    regressor = model().fit(X_train_scaled, y_train)
    y_pred = regressor.predict(X_test_scaled)
    print(y_pred)

    mae.append(mean_absolute_error(y_true = y_test, y_pred=y_pred))
    mse.append(mean_squared_error(y_true = y_test, y_pred=y_pred))
    rmse.append(np.sqrt(mean_squared_error(y_true = y_test, y_pred=y_pred)))
    evs.append(explained_variance_score(y_true = y_test, y_pred=y_pred))
    r_squared_score.append(r2_score(y_true = y_test, y_pred=y_pred))
# Out:
# [ 609894.63901093  916531.25153437  663471.75121297 ... -207158.85462365
#  1611489.48287062  745805.75179814]
# [ 609890.22618588  916541.85184823  663502.55384051 ... -207166.78217411
#  1611508.5897595   745831.31846713]
# [ 609892.87964943  916531.68543056  663474.54866316 ... -207155.59280742
#  1611490.43050034  745805.31186769]
# [554368.1687832  555229.02331957 555035.85891764 ... 553950.53991914
#  555714.87312364 555032.10836973]
# [ 550000.  815000.  749000. ...  199000. 1700000.  800000.]
# [ 537273.33333333  827800.          652370.         ...  181650.
#  1704622.5         732470.        ]

# %%
ml_models_df = pd.DataFrame({
    "Models": ["LinearRegression", "Ridge", "Lasso", "SVR", "DecisionTreeRegressor", "RandomForestRegressor"],
    "mean_absolute_error":mae,
    "mean_squared_error":mse,
    "root_mean_squared_error":rmse,
    "explained_variance_score":evs,
    "r2_score":r_squared_score

})

ml_models_df.set_index("Models", inplace=True)
ml_models_df
# Out:
#                        mean_absolute_error  mean_squared_error  \
# Models
# LinearRegression             270609.044982        2.316335e+11
# Ridge                        270592.910069        2.316328e+11
# Lasso                        270608.406386        2.316335e+11
# SVR                          410828.311381        7.981323e+11
# DecisionTreeRegressor        131663.093307        2.822332e+11
# RandomForestRegressor        104946.021188        4.664728e+10
#
#                        root_mean_squared_error  explained_variance_score  \
# Models
# LinearRegression                 481283.201357                  0.688639
# Ridge                            481282.444606                  0.688640
# Lasso                            481283.153854                  0.688639
# SVR                              893382.492125                  0.000843
# DecisionTreeRegressor            531256.253484                  0.620664
# ...

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

params_grid = {
    LinearRegression:{},
    Ridge:{
        "alpha":[0.1,1.0,10.0]
    },
    Lasso:{
        "alpha":[0.001,0.01,0.1,1.0]
    },
    SVR:{
        "kernel":['rbf', 'linear'],
        "C":[0.1,1,10],
        'epsilon':[0.01,0.1,0.5]
    },
    DecisionTreeRegressor : {
        "max_depth":[None, 5,10,20],
        "min_samples_split":[2,5,10]
    },
    RandomForestRegressor:{
        "n_estimators":[50,100,200],
        "max_depth":[None, 5,10,20],
        "min_samples_split":[2,5,10]
    }
}

# metric list

models = [LinearRegression, Ridge, Lasso, SVR, DecisionTreeRegressor, RandomForestRegressor]

mae = []
mse = []
rmse=[]
evs = []
r_squared_score = []
best_models = []

for model in models:
    print(f"Tuning:{model.__name__}")
    if params_grid[model]:
        grid = GridSearchCV(model(), param_grid=params_grid[model], cv=5, scoring='r2', n_jobs=-1)
        grid.fit(X_train_scaled,y_train)
        regressor = grid.best_estimator_
        print("Best Parameter:", grid.best_params_)
    else:
        regressor = model().fit(X_train_scaled, y_train)


    y_pred = regressor.predict(X_test_scaled)
    print(y_pred)

    mae.append(mean_absolute_error(y_true = y_test, y_pred=y_pred))
    mse.append(mean_squared_error(y_true = y_test, y_pred=y_pred))
    rmse.append(np.sqrt(mean_squared_error(y_true = y_test, y_pred=y_pred)))
    evs.append(explained_variance_score(y_true = y_test, y_pred=y_pred))
    r_squared_score.append(r2_score(y_true = y_test, y_pred=y_pred))
    best_models.append(regressor)
# Out:
# Tuning:LinearRegression
# [ 609894.63901093  916531.25153437  663471.75121297 ... -207158.85462365
#  1611489.48287062  745805.75179814]
# Tuning:Ridge
# Best Parameter: {'alpha': 10.0}
# [ 609848.95499626  916635.02338839  663778.05893461 ... -207233.9463965
#  1611675.71985367  746059.35488101]
# Tuning:Lasso
# Best Parameter: {'alpha': 1.0}
# [ 609892.87964943  916531.68543056  663474.54866316 ... -207155.59280742
#  1611490.43050034  745805.31186769]
# Tuning:SVR
# Best Parameter: {'C': 10, 'epsilon': 0.01, 'kernel': 'linear'}
# [513912.42858541 648002.82440291 605849.97681002 ... 307275.24200316
#  798089.80149236 602013.98584342]
# Tuning:DecisionTreeRegressor
# Best Parameter: {'max_depth': 20, 'min_samples_split': 2}
# [ 526700.          769755.10204082  749000.         ...  199000.
#  1700000.          635000.        ]
# Tuning:RandomForestRegressor
# Best Parameter: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50}
# ...

# %%
ml_models_df = pd.DataFrame({
    "Models": ["LinearRegression", "Ridge", "Lasso", "SVR", "DecisionTreeRegressor", "RandomForestRegressor"],
    "mean_absolute_error":mae,
    "mean_squared_error":mse,
    "root_mean_squared_error":rmse,
    "explained_variance_score":evs,
    "r2_score":r_squared_score

})

ml_models_df.set_index("Models", inplace=True)
ml_models_df
# Out:
#                        mean_absolute_error  mean_squared_error  \
# Models
# LinearRegression             270609.044982        2.316335e+11
# Ridge                        270448.550858        2.316272e+11
# Lasso                        270608.406386        2.316335e+11
# SVR                          309836.020196        5.852022e+11
# DecisionTreeRegressor        124811.435986        1.088654e+11
# RandomForestRegressor        107983.117573        6.851628e+10
#
#                        root_mean_squared_error  explained_variance_score  \
# Models
# LinearRegression                 481283.201357                  0.688639
# Ridge                            481276.584358                  0.688647
# Lasso                            481283.153854                  0.688639
# SVR                              764985.114997                  0.263378
# DecisionTreeRegressor            329947.613101                  0.853668
# ...

# %%
best_models
# Out:
# [LinearRegression(),
#  Ridge(alpha=10.0),
#  Lasso(),
#  SVR(C=10, epsilon=0.01, kernel='linear'),
#  DecisionTreeRegressor(max_depth=20),
#  RandomForestRegressor(max_depth=20, min_samples_split=10, n_estimators=50)]

# %% [markdown]
# # Saving the Trained Model

# %%
import pickle
model_save_dir = "./saved_models/"
os.makedirs(model_save_dir, exist_ok=True)

for model in best_models:
    model_name = type(model).__name__
    model.fit(X_train_scaled, y_train)
    filename = f"{model_name}.pkl"
    print(f"Saving: {filename}")
    model_path = os.path.join(model_save_dir, filename)

    with open(model_path, 'wb') as f:
        pickle.dump(model, f)
    
    print(f"Trained and saved: {filename}")
# Out:
# Saving: LinearRegression.pkl
# Trained and saved: LinearRegression.pkl
# Saving: Ridge.pkl
# Trained and saved: Ridge.pkl
# Saving: Lasso.pkl
# Trained and saved: Lasso.pkl
# Saving: SVR.pkl
# Trained and saved: SVR.pkl
# Saving: DecisionTreeRegressor.pkl
# Trained and saved: DecisionTreeRegressor.pkl
# Saving: RandomForestRegressor.pkl
# Trained and saved: RandomForestRegressor.pkl

# %% [markdown]
# # saving the scaled data

# %%
os.makedirs("./saved_scaling/", exist_ok=True)
with open("./saved_scaling/scaler.pkl", 'wb') as f:
    pickle.dump(scaler,f)

# %%
# checking the model performance
model_path = './saved_models/RandomForestRegressor.pkl'
with open(model_path, 'rb') as f:
    random_forest_model = pickle.load(f)

random_forest_model
# Out:
# RandomForestRegressor(max_depth=20, min_samples_split=10, n_estimators=50)

# %%
random_forest_model.score(X_train_scaled,y_train)
# Out:
# 0.9522563993211316

# %%
random_forest_model.score(X_test_scaled, y_test)
# Out:
# 0.9015475294110096
